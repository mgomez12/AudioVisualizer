# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.genfromtxt("build/out.csv", delimiter=",", filling_values=0)
b = np.genfromtxt("build/wave.csv", delimiter=",", filling_values=0)
print(a.shape)
print(b)
# Out:
# (2000, 2050)
# [    0.     0.     0. ... -1135.  -871.     0.]

# %%
plt.plot(a)

# %%
print(len(b))
plt.plot(b)
print(b.shape)
# Out:
# 515841
# (515841,)
